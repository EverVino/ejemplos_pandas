# %% [markdown]
# ## Por qué Pandas?
#
# Pandas permite una mejor manipulaciones dunhashable type: 'Series'unhashable type: 'Series'unhashable type: 'Series'e datosy combinado con python hace que el tratamiento de datos sea muy flexible.

# %%
# Base se datos descargada de https://github.com/owid/covid-19-data/blob/master/public/data/README.md
# Importante pandas
import pandas as pd
df = pd.read_csv("owid-covid-data.csv")
# df_xlsx = pd.read_excel("")
print(df.head(10))
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan  2020-03-04          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# ...

# %%
print(df.columns)
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
print(df["location"])
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 205916       Zimbabwe
# 205917       Zimbabwe
# 205918       Zimbabwe
# 205919       Zimbabwe
# 205920       Zimbabwe
# Name: location, Length: 205921, dtype: object

# %%
print(df[["location", "total_deaths", "new_deaths"]])
# Out:
#            location  total_deaths  new_deaths
# 0       Afghanistan           NaN         NaN
# 1       Afghanistan           NaN         NaN
# 2       Afghanistan           NaN         NaN
# 3       Afghanistan           NaN         NaN
# 4       Afghanistan           NaN         NaN
# ...             ...           ...         ...
# 205916     Zimbabwe        5577.0         1.0
# 205917     Zimbabwe        5577.0         0.0
# 205918     Zimbabwe        5577.0         0.0
# 205919     Zimbabwe        5577.0         0.0
# 205920     Zimbabwe        5578.0         1.0
#
# [205921 rows x 3 columns]

# %%
print(df.iloc[1:4])
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 1                         0.5            64.83                    0.511
# ...

# %%
print(df.iloc[2,1])
# Out:
# Asia

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.975550e+05  1.973040e+05        1.961270e+05  1.787970e+05
# mean   3.785280e+06  1.253950e+04        1.254970e+04  6.879966e+04
# std    2.376460e+07  8.716845e+04        8.517905e+04  3.566209e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    3.341500e+03  0.000000e+00        6.714000e+00  1.030000e+02
# 50%    4.101900e+04  6.500000e+01        1.004290e+02  1.022000e+03
# 75%    4.403765e+05  1.013000e+03        1.147000e+03  9.060000e+03
# max    5.794457e+08  4.079561e+06        3.438024e+06  6.405438e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  178771.000000        177604.000000            196647.000000
# mean      148.655073           149.437136             49544.108349
# std       762.698476           746.318219             90527.530977
# min         0.000000             0.000000                 0.001000
# ...

# %%
df.sort_values("total_cases", ascending = False)
# Out:
#         iso_code      continent                      location        date  \
# 203341  OWID_WRL            NaN                         World  2022-08-02
# 203340  OWID_WRL            NaN                         World  2022-08-01
# 203339  OWID_WRL            NaN                         World  2022-07-31
# 203338  OWID_WRL            NaN                         World  2022-07-30
# 203337  OWID_WRL            NaN                         World  2022-07-29
# ...          ...            ...                           ...         ...
# 195786       VIR  North America  United States Virgin Islands  2022-06-16
# 195787       VIR  North America  United States Virgin Islands  2022-06-17
# 195788       VIR  North America  United States Virgin Islands  2022-06-18
# 195789       VIR  North America  United States Virgin Islands  2022-06-19
# 202417       ESH         Africa                Western Sahara  2022-04-20
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df_SA = df.loc[df["continent"] == "South America"]
df_SA
# Out:
#        iso_code      continent   location        date  total_cases  new_cases  \
# 7054        ARG  South America  Argentina  2020-01-01          NaN        NaN
# 7055        ARG  South America  Argentina  2020-01-02          NaN        NaN
# 7056        ARG  South America  Argentina  2020-01-03          NaN        NaN
# 7057        ARG  South America  Argentina  2020-01-04          NaN        NaN
# 7058        ARG  South America  Argentina  2020-01-05          NaN        NaN
# ...         ...            ...        ...         ...          ...        ...
# 200836      VEN  South America  Venezuela  2022-07-29     534906.0      455.0
# 200837      VEN  South America  Venezuela  2022-07-30     535277.0      371.0
# 200838      VEN  South America  Venezuela  2022-07-31     535836.0      559.0
# 200839      VEN  South America  Venezuela  2022-08-01     536086.0      250.0
# 200840      VEN  South America  Venezuela  2022-08-02     536086.0        NaN
#
# ...

# %%
df["new_var"] = sf["var1"] + df["var2"]
df.drop(columns = ["var1"]) # To Eliminate columns
df = df[cols[:4] + [cols[-1]]] # Modificando la tabla
df.to_csv("name.csv", index=False) # Para grabar datos en un nuevo archivo
df.to_excel("name.xlsx", index = False)

# %%
# Filtering data
new_df = df.loc[(df["location"]== "Bolivia") | (df["location"] == "Peru")] # & for and and | for or

# %%
new_df.reset_index()
# Out:
#        index iso_code      continent location        date  total_cases  \
# 0      22189      BOL  South America  Bolivia  2020-03-11          2.0
# 1      22190      BOL  South America  Bolivia  2020-03-12          2.0
# 2      22191      BOL  South America  Bolivia  2020-03-13          3.0
# 3      22192      BOL  South America  Bolivia  2020-03-14         10.0
# 4      22193      BOL  South America  Bolivia  2020-03-15         10.0
# ...      ...      ...            ...      ...         ...          ...
# 1750  147519      PER  South America     Peru  2022-07-29    3889029.0
# 1751  147520      PER  South America     Peru  2022-07-30    3895496.0
# 1752  147521      PER  South America     Peru  2022-07-31    3909870.0
# 1753  147522      PER  South America     Peru  2022-08-01    3914506.0
# 1754  147523      PER  South America     Peru  2022-08-02    3923744.0
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# ...

# %%
new_america = df[(df["continent"]=="North America") | (df["continent"] == "South America")]
new_america
# Out:
#        iso_code      continent   location        date  total_cases  new_cases  \
# 5323        AIA  North America   Anguilla  2020-03-28          2.0        2.0
# 5324        AIA  North America   Anguilla  2020-03-29          2.0        0.0
# 5325        AIA  North America   Anguilla  2020-03-30          2.0        0.0
# 5326        AIA  North America   Anguilla  2020-03-31          2.0        0.0
# 5327        AIA  North America   Anguilla  2020-04-01          2.0        0.0
# ...         ...            ...        ...         ...          ...        ...
# 200836      VEN  South America  Venezuela  2022-07-29     534906.0      455.0
# 200837      VEN  South America  Venezuela  2022-07-30     535277.0      371.0
# 200838      VEN  South America  Venezuela  2022-07-31     535836.0      559.0
# 200839      VEN  South America  Venezuela  2022-08-01     536086.0      250.0
# 200840      VEN  South America  Venezuela  2022-08-02     536086.0        NaN
#
# ...

# %%
new_data = df[["location", "new_cases", "date"]]
new_data
# Out:
#            location  new_cases        date
# 0       Afghanistan        5.0  2020-02-24
# 1       Afghanistan        0.0  2020-02-25
# 2       Afghanistan        0.0  2020-02-26
# 3       Afghanistan        0.0  2020-02-27
# 4       Afghanistan        0.0  2020-02-28
# ...             ...        ...         ...
# 205916     Zimbabwe       40.0  2022-07-29
# 205917     Zimbabwe        0.0  2022-07-30
# 205918     Zimbabwe        2.0  2022-07-31
# 205919     Zimbabwe        4.0  2022-08-01
# 205920     Zimbabwe       21.0  2022-08-02
#
# [205921 rows x 3 columns]

# %%
df.loc[df["location"] == "Bolivia","location"] = "BOLIVIA" # para hacer cambios condicionales

# %%
df.groupby(["new_deaths"]).mean().srt_values("ewn_cases" , ascending =False) # sum() count()
